# %%
import sys

sys.path.append("../..")

# %%
from typing import Dict

import numpy as np
import pandas as pd
import torch
from scipy.stats import mode
from torch_geometric.seed import seed_everything

from torch_frame.data.stats import StatType
 
from relbench.base import Dataset, EntityTask, Table, TaskType
from relbench.datasets import get_dataset, get_dataset_names
from relbench.tasks import get_task, get_task_names

import ctu_relational
from ctu_relational.tasks import CTUEntityTask

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 200)
# %reload_ext autoreload
# %autoreload 2

# %%
device = torch.device("cpu")
seed_everything(42)

# %%
def evaluate(
    task: CTUEntityTask, train_table: Table, pred_table: Table, name: str
) -> Dict[str, float]:
    is_test = task.target_col not in pred_table.df
    if name == "global_zero":
        pred = np.zeros(len(pred_table))
    elif name == "global_mean":
        mean = train_table.df[task.target_col].astype(float).values.mean()
        pred = np.ones(len(pred_table)) * mean
    elif name == "global_median":
        median = np.median(train_table.df[task.target_col].astype(float).values)
        pred = np.ones(len(pred_table)) * median

    elif name == "random":
        pred = np.random.rand(len(pred_table))
    elif name == "majority":
        past_target = train_table.df[task.target_col].astype(int)
        majority_label = int(past_target.mode().iloc[0])
        pred = np.ones(len(pred_table), float) * majority_label

    elif name == "majority_multiclass":
        past_target = train_table.df[task.target_col]
        majority = int(past_target.mode().iloc[0])
        num_labels = len(task.stats[StatType.COUNT][0])
        pred = np.zeros((len(pred_table.df), num_labels), float)
        pred[:, majority] = 1
    elif name == "random_multiclass":
        num_labels = len(task.stats[StatType.COUNT][0])
        pred = np.random.rand(len(pred_table), num_labels)

    elif name == "majority_multilabel":
        past_target = train_table.df[task.target_col]
        majority = mode(np.stack(past_target.values), axis=0).mode[0]
        pred = np.stack([majority] * len(pred_table.df))
    elif name == "random_multilabel":
        num_labels = train_table.df[task.target_col].values[0].shape[0]
        pred = np.random.rand(len(pred_table), num_labels)

    else:
        raise ValueError("Unknown eval name called {name}.")
    return task.evaluate(pred, None if is_test else pred_table)

# %%
ctu_datasets = list(filter(lambda x: x.startswith("ctu"), get_dataset_names()))

# %%
regression_info = {}
classification_info = {}

for dataset_name in ctu_datasets:
    print(f"Processing {dataset_name}")
    for task_name in get_task_names(dataset_name):
        task: CTUEntityTask = get_task(dataset_name, task_name)

        if task.task_type in [TaskType.LINK_PREDICTION, TaskType.MULTILABEL_CLASSIFICATION]:
            continue

        stats = {}

        train_table = task.get_table("train")
        val_table = task.get_table("val")
        test_table = task.get_table("test", mask_input_cols=False)

        trainval_table_df = pd.concat([train_table.df, val_table.df], axis=0)
        trainval_table = Table(
            df=trainval_table_df,
            fkey_col_to_pkey_table=train_table.fkey_col_to_pkey_table,
            pkey_col=train_table.pkey_col,
            time_col=train_table.time_col,
        )

        if task.task_type == TaskType.REGRESSION:
            eval_name_list = ["global_zero", "global_mean", "global_median"]
            info = regression_info
            stats = {k.name: v for k, v in task.stats.items()}

        elif task.task_type in [TaskType.BINARY_CLASSIFICATION]:
            eval_name_list = ["random", "majority"]
            info = classification_info
            stats = {"class_count": len(task.stats[StatType.COUNT][0])}

        elif task.task_type in [TaskType.MULTICLASS_CLASSIFICATION]:
            eval_name_list = ["random_multiclass", "majority_multiclass"]
            info = classification_info
            stats = {"class_count": len(task.stats[StatType.COUNT][0])}

        info[task_name] = {
            "dataset_name": dataset_name,
            "task_name": task_name,
            "task_type": task.task_type.name,
            **stats,
            "num_train": len(train_table),
            "num_val": len(val_table),
            "num_test": len(test_table),
        }

        for name in eval_name_list:
            for m, v in evaluate(task, train_table, train_table, name=name).items():
                info[task_name][f"train_{name}_{m}"] = v

            for m, v in evaluate(task, train_table, val_table, name=name).items():
                info[task_name][f"val_{name}_{m}"] = v

            for m, v in evaluate(task, trainval_table, test_table, name=name).items():
                info[task_name][f"test_{name}_{m}"] = v

        regression_info_df = pd.DataFrame(regression_info).T
        regression_info_df.to_csv("./regression_info.csv", index=False)
        classification_info_df = pd.DataFrame(classification_info).T
        classification_info_df.to_csv("./classification_info.csv", index=False)
# Out:
# Processing ctu-accidents
# Loading Database object from /home/jakub/.cache/relbench/ctu-accidents/db...
# Done in 0.60 seconds.
# Processing ctu-adventureworks
# Making task table for train split from scratch...
# (You can also use `get_task(..., download=True)` for tasks prepared by the RelBench team.)
# Loading Database object from /home/jakub/.cache/relbench/ctu-adventureworks/db...
# Done in 0.30 seconds.
# Done in 0.34 seconds.
# Making task table for val split from scratch...
# (You can also use `get_task(..., download=True)` for tasks prepared by the RelBench team.)
# Done in 0.02 seconds.
# Making task table for test split from scratch...
# (You can also use `get_task(..., download=True)` for tasks prepared by the RelBench team.)
# Done in 0.02 seconds.
# Making task table for train split from scratch...
# (You can also use `get_task(..., download=True)` for tasks prepared by the RelBench team.)
# Done in 0.02 seconds.
# Making task table for val split from scratch...
# (You can also use `get_task(..., download=True)` for tasks prepared by the RelBench team.)
# Done in 0.02 seconds.
# Making task table for test split from scratch...
# (You can also use `get_task(..., download=True)` for tasks prepared by the RelBench team.)
# Done in 0.01 seconds.
# Processing ctu-airline
# Loading Database object from /home/jakub/.cache/relbench/ctu-airline/db...
# Done in 0.43 seconds.
# Processing ctu-atherosclerosis
# Loading Database object from /home/jakub/.cache/relbench/ctu-atherosclerosis/db...
# Done in 0.04 seconds.
# Processing ctu-basketballmen
# Loading Database object from /home/jakub/.cache/relbench/ctu-basketballmen/db...
# Done in 0.05 seconds.
# Processing ctu-basketballwomen
# Loading Database object from /home/jakub/.cache/relbench/ctu-basketballwomen/db...
# Done in 0.03 seconds.
# Processing ctu-biodegradability
# Loading Database object from /home/jakub/.cache/relbench/ctu-biodegradability/db...
# Done in 0.01 seconds.
# Processing ctu-bupa
# Loading Database object from /home/jakub/.cache/relbench/ctu-bupa/db...
# Done in 0.01 seconds.
# Processing ctu-carcinogenesis
# Loading Database object from /home/jakub/.cache/relbench/ctu-carcinogenesis/db...
# Done in 0.01 seconds.
# Processing ctu-cde
# Loading Database object from /home/jakub/.cache/relbench/ctu-cde/db...
# Done in 0.06 seconds.
# Processing ctu-chess
# Loading Database object from /home/jakub/.cache/relbench/ctu-chess/db...
# Done in 0.01 seconds.
# Processing ctu-classicmodels
# Loading Database object from /home/jakub/.cache/relbench/ctu-classicmodels/db...
# Done in 0.01 seconds.
# Processing ctu-cora
# Loading Database object from /home/jakub/.cache/relbench/ctu-cora/db...
# Done in 0.01 seconds.
# Processing ctu-countries
# Loading Database object from /home/jakub/.cache/relbench/ctu-countries/db...
# Done in 0.02 seconds.
# Processing ctu-craftbeer
# Loading Database object from /home/jakub/.cache/relbench/ctu-craftbeer/db...
# Done in 0.00 seconds.
# Processing ctu-credit
# Processing ctu-dallas
# Loading Database object from /home/jakub/.cache/relbench/ctu-dallas/db...
# Done in 0.01 seconds.
# Processing ctu-dcg
# Loading Database object from /home/jakub/.cache/relbench/ctu-dcg/db...
# Done in 0.00 seconds.
# Processing ctu-diabetes
# Loading Database object from /home/jakub/.cache/relbench/ctu-diabetes/db...
# Done in 0.10 seconds.
# Processing ctu-dunur
# Processing ctu-elti
# Processing ctu-employee
# Loading Database object from /home/jakub/.cache/relbench/ctu-employee/db...
# Done in 0.19 seconds.
# Processing ctu-ergastf1
# Loading Database object from /home/jakub/.cache/relbench/ctu-ergastf1/db...
# Done in 0.08 seconds.
# Processing ctu-expenditures
# Loading Database object from /home/jakub/.cache/relbench/ctu-expenditures/db...
# Done in 0.16 seconds.
# Processing ctu-financial
# Loading Database object from /home/jakub/.cache/relbench/ctu-financial/db...
# Done in 0.28 seconds.
# Processing ctu-fnhk
# Loading Database object from /home/jakub/.cache/relbench/ctu-fnhk/db...
# Done in 0.07 seconds.
# Processing ctu-ftp
# Loading Database object from /home/jakub/.cache/relbench/ctu-ftp/db...
# Done in 0.02 seconds.
# Processing ctu-geneea
# Loading Database object from /home/jakub/.cache/relbench/ctu-geneea/db...
# Done in 0.12 seconds.
# Processing ctu-genes
# Loading Database object from /home/jakub/.cache/relbench/ctu-genes/db...
# Done in 0.01 seconds.
# Processing ctu-gosales
# Loading Database object from /home/jakub/.cache/relbench/ctu-gosales/db...
# Done in 0.01 seconds.
# Processing ctu-grants
# Loading Database object from /home/jakub/.cache/relbench/ctu-grants/db...
# Done in 2.00 seconds.
# Processing ctu-hepatitis
# Loading Database object from /home/jakub/.cache/relbench/ctu-hepatitis/db...
# Done in 0.01 seconds.
# Processing ctu-hockey
# Loading Database object from /home/jakub/.cache/relbench/ctu-hockey/db...
# Done in 0.12 seconds.
# Processing ctu-imdb
# Loading Database object from /home/jakub/.cache/relbench/ctu-imdb/db...
# Done in 0.63 seconds.
# Processing ctu-lahman
# Loading Database object from /home/jakub/.cache/relbench/ctu-lahman/db...
# Done in 0.15 seconds.
# Processing ctu-legalacts
# Loading Database object from /home/jakub/.cache/relbench/ctu-legalacts/db...
# Done in 0.73 seconds.
# Processing ctu-mesh
# Loading Database object from /home/jakub/.cache/relbench/ctu-mesh/db...
# Done in 0.04 seconds.
# Processing ctu-mondial
# Loading Database object from /home/jakub/.cache/relbench/ctu-mondial/db...
# Done in 0.18 seconds.
# Processing ctu-mooney
# Processing ctu-movielens
# Loading Database object from /home/jakub/.cache/relbench/ctu-movielens/db...
# Done in 0.06 seconds.
# Processing ctu-musklarge
# Loading Database object from /home/jakub/.cache/relbench/ctu-musklarge/db...
# Done in 0.02 seconds.
# Processing ctu-musksmall
# Loading Database object from /home/jakub/.cache/relbench/ctu-musksmall/db...
# Done in 0.02 seconds.
# Processing ctu-mutagenesis
# Loading Database object from /home/jakub/.cache/relbench/ctu-mutagenesis/db...
# Done in 0.01 seconds.
# Processing ctu-ncaa
# Loading Database object from /home/jakub/.cache/relbench/ctu-ncaa/db...
# Done in 0.05 seconds.
# Processing ctu-northwind
# Loading Database object from /home/jakub/.cache/relbench/ctu-northwind/db...
# Done in 0.02 seconds.
# Processing ctu-pima
# Loading Database object from /home/jakub/.cache/relbench/ctu-pima/db...
# Done in 0.01 seconds.
# Processing ctu-premiereleague
# Loading Database object from /home/jakub/.cache/relbench/ctu-premiereleague/db...
# Done in 0.04 seconds.
# Processing ctu-restbase
# Loading Database object from /home/jakub/.cache/relbench/ctu-restbase/db...
# Done in 0.01 seconds.
# Processing ctu-sakila
# Loading Database object from /home/jakub/.cache/relbench/ctu-sakila/db...
# Done in 0.03 seconds.
# Processing ctu-sales
# Loading Database object from /home/jakub/.cache/relbench/ctu-sales/db...
# Done in 0.50 seconds.
# Processing ctu-samegen
# Processing ctu-sap
# Loading Database object from /home/jakub/.cache/relbench/ctu-sap/db...
# Done in 0.20 seconds.
# Processing ctu-satellite
# Processing ctu-seznam
# Loading Database object from /home/jakub/.cache/relbench/ctu-seznam/db...
# Done in 0.15 seconds.
# Processing ctu-sfscores
# Loading Database object from /home/jakub/.cache/relbench/ctu-sfscores/db...
# Done in 0.02 seconds.
# Processing ctu-shakespeare
# Processing ctu-stats
# Loading Database object from /home/jakub/.cache/relbench/ctu-stats/db...
# Done in 1.07 seconds.
# Processing ctu-studentloan
# Loading Database object from /home/jakub/.cache/relbench/ctu-studentloan/db...
# Done in 0.01 seconds.
# Processing ctu-thrombosis
# Loading Database object from /home/jakub/.cache/relbench/ctu-thrombosis/db...
# Done in 0.03 seconds.
# Processing ctu-toxicology
# Loading Database object from /home/jakub/.cache/relbench/ctu-toxicology/db...
# Done in 0.01 seconds.
# Processing ctu-tpcc
# Loading Database object from /home/jakub/.cache/relbench/ctu-tpcc/db...
# Done in 0.23 seconds.
# Processing ctu-tpcd
# Loading Database object from /home/jakub/.cache/relbench/ctu-tpcd/db...
# Done in 3.29 seconds.
# Processing ctu-tpcds
# Loading Database object from /home/jakub/.cache/relbench/ctu-tpcds/db...
# Done in 3.91 seconds.
# Processing ctu-tpch
# Loading Database object from /home/jakub/.cache/relbench/ctu-tpch/db...
# Done in 3.14 seconds.
# Processing ctu-triazine
# Loading Database object from /home/jakub/.cache/relbench/ctu-triazine/db...
# Done in 0.00 seconds.
# Processing ctu-uwcse
# Loading Database object from /home/jakub/.cache/relbench/ctu-uwcse/db...
# Done in 0.01 seconds.
# Processing ctu-visualgenome
# Loading Database object from /home/jakub/.cache/relbench/ctu-visualgenome/db...
# Done in 0.36 seconds.
# Processing ctu-voc
# Making task table for train split from scratch...
# (You can also use `get_task(..., download=True)` for tasks prepared by the RelBench team.)
# Loading Database object from /home/jakub/.cache/relbench/ctu-voc/db...
# Done in 0.04 seconds.
# Done in 0.05 seconds.
# Making task table for val split from scratch...
# (You can also use `get_task(..., download=True)` for tasks prepared by the RelBench team.)
# Done in 0.01 seconds.
# Making task table for test split from scratch...
# (You can also use `get_task(..., download=True)` for tasks prepared by the RelBench team.)
# Done in 0.01 seconds.
# Processing ctu-walmart
# Loading Database object from /home/jakub/.cache/relbench/ctu-walmart/db...
# Done in 0.15 seconds.
# Processing ctu-webkp
# Loading Database object from /home/jakub/.cache/relbench/ctu-webkp/db...
# Done in 0.02 seconds.
# Processing ctu-world
# Loading Database object from /home/jakub/.cache/relbench/ctu-world/db...
# Done in 0.01 seconds.
